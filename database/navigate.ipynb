# %%
import pandas as pd
import sqlite3

conn = sqlite3.connect("../plantes.db")

# Voir toutes les plantes
df = pd.read_sql("SELECT * FROM plantes", conn)
display(df)
# Out:
#    id                                                url  \
# 0   1  https://www.promessedefleurs.com/arbustes/arbu...
# 1   2  https://www.promessedefleurs.com/bulbes-d-ete/...
# 2   3  https://www.promessedefleurs.com/bulbes-d-ete/...
# 3   4  https://www.promessedefleurs.com/arbustes/arbu...
# 4   5  https://www.promessedefleurs.com/bulbes-de-pri...
#
#                                        nom_complet  \
# 0       Camélia d'automne - Camellia sasanqua Yume
# 1  Collection bulbes pour Bouquets modernes blancs
# 2            Glaïeul ou Gladiolus White Prosperity
# 3           Eucalyptus Baby Blue - Gommier argenté
# 4                                Muscari neglectum
#
#                                         nom_commun  \
# 0                                Camélia d'automne
# 1  Collection bulbes pour Bouquets modernes blancs
# 2                                             None
# 3                                             None
# ...

# %%
df=[]
# Out:
# Empty DataFrame
# Columns: []
# Index: []
